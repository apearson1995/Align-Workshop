# %% [markdown]
# # Align Workshop 1: Phylogenetic Inference

# %% [markdown]
# ## Outline

# %% [markdown]
# 1. Motivation
# 2. Intro to Programming
#     * Visualizing the problem of HIV and Dentist
# 3. Intro to Statistical Inference
#     * Introduction to the Mann-Whitney Test (If Time Permits)
# 4. Conclusion Excercise 1

# %% [markdown]
# # Motivation

# %% [markdown]
# A lot of comp bio research these days in some way or another involves gene sequencing. During the past 15 years we have seen the cost of sequencing the DNA of an entire organism decrease exponentially with an average decay rate much higher than 2 thus oustripping "Moore's Law" (Which as some of you may know was a prediction made by Gordon E. Moore in  1965 that the number the number of transistors (on-off switches in computers that perform computation) that engineers are able to put per unit area will double every 18 months.)

# %%
# Ignore this code
import IPython.display 
seq_cost = IPython.display.Image("https://www.genome.gov/images/content/costpergenome2015_4.jpg")
seq_cost

# %% [markdown]
# One of the many things that we can do with this DNA is to try and map out the evolutionary relationships between different organisms.  This is interesting in both the pure abstract scientific viewpoint as well as a more applied perspective.  For instance mapping the relationships between people can help epidemiologists figure out how a virus such as HIV spreads within a community of people. This question became particularly relevant in the 90's when a Dentist by the name of Dr. Acer was accused of infecting his patients with HIV. We will study this case in more depth towards the end of this workshop.

# %% [markdown]
# *Ask on Run through: Quick Summary sequence Alignment*
#
# For the duration of this workshop we will assume that we are given aligned strands of a DNA sequence.
#
# In particular we will simplify the problem down to being given an input of different sequences of DNA, for example S, M, and B, and will accurately map their corresponding evolutionary histories.

# %%
# Ignore this code
import IPython.display 
phylo_tree = IPython.display.Image("https://upload.wikimedia.org/wikipedia/commons/3/3f/Possible_evolutionary_trees_for_the_phylum_rotifera.png")
phylo_tree

# %% [markdown]
# ### Discussion Question: Assuming we have different sequences of *aligned* DNA what "statistic" (number evaluated from observing the data) could we calculate to estimate "closeness" of two strands of DNA ?

# %% [markdown]
# **Answer:** Proportion of different bases between S,M, and B respectively.

# %% [markdown]
# This problem is perfect for computers. Not only because computers are so powerful and DNA/RNA strands are so long, but also because there is such a well defined notion of an input and an output.

# %%
# Ignore this code
import IPython.display 
phylo_tree = IPython.display.Image("https://upload.wikimedia.org/wikipedia/commons/thumb/3/3b/Function_machine2.svg/220px-Function_machine2.svg.png")
phylo_tree

# %% [markdown]
# ## Quick Intro to Computing

# %%
# Ignore this code
from data import *
from library import *
from tests import *
import numpy as np

# %% [markdown]
# Our end goal is to make our computer, when given input of two sequences of the same length,  output  the proportion of different bases between two strands of RNA/DNA. So let us try and first construct an "Algorithm" which is just a fancy CS term that refers to a series of steps given to accomplish a task.  You can think of it as a blueprint of sorts that we will use as a rough draft when we actually make our code.

# %% [markdown]
# ## Your Turn:

# %% [markdown]
# Compare each nucleotide in the DNA sequences element-wise(explain further with slide). If they are different then we need to store that information somehow and keep track of the number that are the same. After comparing all of the nucleotides we need to divide the number of nucleotides by the number of total nucleotides in the strand to get the proportion of differences.

# %% [markdown]
# But to bring such an algorithm into fruition in the real world we must first learn some of the basics of how we are acquiring the data and how the data is represented by the computer.

# %% [markdown]
# ## Natural Question: How are strands of Aligned DNA/RNA put into and represented in a computer? More broadly, what is the process of dealing with DNA in computational Biology?

# %% [markdown]
# There exist machines that given genetic material can extract the necsseray information (i.e. the sequence), which can then be  **Double Check**

# %% [markdown]
# ### What is a string?

# %% [markdown]
# Roughly high level picture is putting quotes around any number of characters. For example, below shows two strings that hold DNA sequences. A lot of computing deals with strings and lucky for us the people who made Python created some useful commands for dealing with strings

# %%
string_1 = "GGACTAGCA"
string_2 = "GGACTTTCT"

# %% [markdown]
# Often times in programming you will be given data, that you don't manually enter in the computer but rather are downloaded from othere source (example zip file).

# %% [markdown]
# ### Operations on Strings:

# %% [markdown]
# Wouldn't it be great if we had some way that we can manipulate and analyze strings? Well fortunately there are many "commands" that we can use when dealing with strings. Starting with the basics let's see if we can just get the string to print.

# %%
print(string_1)
# Out:
# GGACTAGCA

# %% [markdown]
# Analysis of Strings (Note Strings are "0-indexed"):

# %%
string_1[0]
# Out:
# 'G'

# %%
## check if two letters are the same
string_1[0] == "G"
# Out:
# True

# %%
### Feel Free to use this cell to play around with == sign using strings, numbers, and whatever else you like

# %% [markdown]
# Notice the == sign above. We can use the double equals sign to check if two things are equal to one another. In particular this == sign can be used in our code for "conditional statements" which are basically just ways that we can control the flow of our code.  For a more concrete example, see below.

# %%
age = 13
if   age >= 60:
    print("Congratulations you are a senior citizen enjoy half off your breakfast at Denny's")
elif age >= 18:
    print("Congratulations you are no longer a child")
else:
    print("Stay in school study hard and don't do drugs")
# Out:
# Stay in school study hard and don't do drugs

# %% [markdown]
# From above we see that we can go through and change age manually, and re-run the cell each time to get age, but that is very time consuming. Wouldn't it be great if we could somehow package this logic in such a way that we can quickly use it on an age without constantly re-running the cell?

# %%
def advice_giver(age):
    if   age >= 60:
        return("Congratulations you are a senior citizen enjoy your breakfast at Denny's")
    elif age >= 18:
        return("Congratulations you are an adult")
    else:
        return("Enjoy Childhood while it lasts")
        
advice_giver(99)
# Out:
# "Congratulations you are a senior citizen enjoy your breakfast at Denny's"

# %% [markdown]
# ## Natural Question:
# Why did we change print to return in the translation from "loose code" to the function?  The reason is a bit technical, but in general when we are writing functions we want to use return instead of print because  because it is easier to "assign" values returned from a "return statement" than a "print statement". See below

# %%
a = advice_giver(2345)
a
# Out:
# "Congratulations you are a senior citizen enjoy your breakfast at Denny's"

# %% [markdown]
# ### What is a "loop", and how can it be used?

# %% [raw]
# A loop is a tool used by programmers to repeat a sequence of instructions until a certain condition is reached. For example, in the while loop below, the inner code is computed until the condition (i being less than the length of the string) is no longer true.

# %%
i     = 0
num_G = 0
while i < len(string_1):
    if string_1[i] == "G":
        num_G = num_G + 1
    i = i + 1
num_G
# Out:
# 3

# %% [markdown]
# ## Your Turn Try to write prop_diff function

# %%
"""
Computes proportion of differing letters from two strings of the same size
Args:
    s1: string 1
    s2: string 2 
Returns:
    proportion (in between 0 and 1) of differing letters
"""

def prop_diff(s1,s2):
    # Your Code Here
    return

# %% [markdown]
# # Your Turn: Try and write prop_diff function

# %%
"""
Computes proportion of differing letters from two strings of the same size
Args:
    s1: string 1
    s2: string 2 
Returns:
    proportion (in between 0 and 1) of differing letters
"""

def prop_diff(s1,s2):
    # Correct Answer
    if len(s1) != len(s2):
        raise ValueError("Cannot compute compare DNA sequences of differing length")
    diffs = 0
    i     = 0
    while i < len(s1):
        if s1[i] != s2[i]:
            diffs += 1
        i += 1
    return float(diffs)/float(len(s1))

# %%
# Run the following code to test your function
test_prop_diff(prop_diff)
# Out:
# 'CONGRTULATIONS YOUR FUNCTION IS CORRECT :) !'

# %% [markdown]
# But this function does not tell all of the story  It turns out it is useful to instead calculate two different proportions of the string, because due to the chemical properties of the molecules some exchanges are more likely to occur than others, and we can improve oujr algorithm by taking this into account.

# %% [markdown]
# # More Sophisticated Distance

# %%
"""
Compute proportion of transitions from two strings of the of the same length. 

Transitions are  (A<->G, C<->T)

Args: 
    s1: string 1
    s2: string 2

Return:
    Error if the strings are not of same length
    Else, return a and b of different letters
"""
def prop_trs(s1,s2):
    # Your Code Here
    return

# %%
"""
Compute proportion of transversions from two strings of the same length. 

Transversions are (A<->C, A<->T, C<->G, G<->T).

Args: 
    s1: string 1
    s2: string 2

Return:
    Error if the strings are not of same length
    Else, return a and b of different letters
"""
def prop_trv(s1,s2):
    # Your Code Here
    return

# %% [markdown]
# ## Try to write the functions

# %%
"""
Compute proportion of transitions from two strings of the of the same length. 

Transitions are  (A<->G, C<->T)

Args: 
    s1: string 1
    s2: string 2

Return:
    Error if the strings are not of same length
    Else, return a and b of different letters
"""
def prop_trs(s1,s2):
    # Your Code Here
    if len(s1) != len(s2):
        raise ValueError("Cannot compute compare DNA sequences of differing length")
    diffs = 0
    i     = 0
    while i < len(s1):
        if s1[i] == "A" and s2[i] == "G":
            diffs += 1
        elif s1[i] == "G" and s2[i] == "A":
            diffs += 1
        elif s1[i] == "C" and s2[i] == "T":
            diffs += 1
        elif s1[i] == "T" and s2[i] == "C":
            diffs += 1
        i += 1
    return float(diffs)/float(len(s1))

# %%
# Run the following code to test your function
# test_prop_trs(prop_trs)

# %% [markdown]
# ## Kind of annoying but as you can see below we can repeat the process

# %%
"""
Compute proportion of transversions from two strings of the same length. 

Transversions are (A<->C, A<->T, C<->G, G<->T).

Args: 
    s1: string 1
    s2: string 2

Return:
    Error if the strings are not of same length
    Else, return a and b of different letters
"""
def prop_trv(s1,s2):
    # Your Code Here
    if len(s1) != len(s2):
        raise ValueError("Cannot compute compare DNA sequences of differing length")
    diffs = 0
    i     = 0
    while i < len(s1):
        if s1[i] == "A" and s2[i] == "C":
            diffs += 1
        elif s1[i] == "C" and s2[i] == "A":
            diffs += 1
        elif s1[i] == "A" and s2[i] == "T":
            diffs += 1
        elif s1[i] == "T" and s2[i] == "A":
            diffs += 1
        elif s1[i] == "C" and s2[i] == "G":
            diffs += 1
        elif s1[i] == "G" and s2[i] == "C":
            diffs += 1
        elif s1[i] == "G" and s2[i] == "T":
            diffs += 1
        elif s1[i] == "T" and s2[i] == "G":
            diffs += 1
        i += 1
    return

# %%
# Run the following code to test your function
# test_prop_trv(prop_trv)

# %% [markdown]
# ## An Apology

# %% [markdown]
# Up until this point we have somewhat dishonestly been suggesting that a way to accurately calculate the distance between any two sequences is by calculating the proportion of different nucleotides between two sequences.  Whereas in reality this technique is never used in tree constructing algorithms. Why it is not used is a discussion for another time, but you can rest easy knowing that a lot of very smart people have been thinking about this problem for a very long time, and have developed some fantastic distance formulas.
#
# For the more matthematically inclined who are familiar with stochastic processes I reccomend reading the wikepidea page on modeling molecular evolution: https://en.wikipedia.org/wiki/Models_of_DNA_evolution. (Also UC Berkeley offers 2 classes: Math 127 and CS 176 that explore these topics in greater depth).
#
# Now before you run for the exits, fed up with our hand-wavy explanations, it is important to note that generally in life, and particularly in programming we have to take on faith that things work in order to build on other people's discoveries. Or perhaps more eloquently...

# %%
import IPython.display 
seq_cost = IPython.display.Image("http://24.media.tumblr.com/tumblr_lxw9g91qS81qfvq9bo1_500.jpg")
seq_cost

# %% [markdown]
# Furthermore, this idea is so important for programming that computer scientists have a specific term for being able to use something without knowing all of the mechanisms by which it operates, namely abstraction. For example, when you drive a car and and push the brake, you don't need to know the exact mechanism of how it stops the car, just that you push a button and the car will slow down. Using abstraction let's us take for granted that the following Algorithm provides a reasonable estimate for the distance between two sequences; the proportion is a key ingredient in all distance functions, yet the actual algorithm involves more advanced mathematics.

# %% [markdown]
# ## Computation: It’s about the community

# %%
community = IPython.display.Image("http://www.occupancyheroes.com/rewards/wp-content/uploads/2014/08/community-events.jpg")
community

# %% [markdown]
# No use in re-inventing the wheel. There is an abundance of very high quality free code in the world. As you can see from the code in your directory i.e. (test.py ,data.py, library.py)
#
# We Could not go deeper into functions because of time constraints and require a lot of pre-requisite knowledge of data

# %% [markdown]
# ## Introduction to Data Structures

# %%
import IPython.display 
IPython.display.Image("https://upload.wikimedia.org/wikipedia/commons/thumb/f/f7/Binary_tree.svg/220px-Binary_tree.svg.png")

# %%
import IPython.display 
IPython.display.Image("https://upload.wikimedia.org/wikipedia/commons/e/e6/Simplified_tree.png")

# %% [markdown]
# A data structure is a specialized format for organizing and storing data. General data structure types include the array, the file, the record, the table, the tree, and so on. Any data structure is designed to organize data to suit a specific purpose so that it can be accessed and worked with in appropriate ways. (Google)

# %% [markdown]
# ## Matrices

# %% [markdown]
# A matrix a rectangular array of quantities or expressions in rows and columns that is treated as a single entity and manipulated according to particular rules.
#
# an organizational structure in which two or more lines of command, responsibility, or communication may run through the same individual.

# %%
import IPython.display 
IPython.display.Image("http://is2.mzstatic.com/image/thumb/Purple2/v4/0e/39/e1/0e39e1bf-c98b-cc25-9ecd-17a100744a64/mzl.qncpgptb.png/0x0ss-85.jpg")

# %%
# Example of Jukes-Cantor Distance
JC_distance("ATTGAC","ATGGCC")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-8305e8dcd231> in <module>()
#       1 # Example of Jukes-Cantor Distance
# ----> 2 JC_distance("ATTGAC","ATGGCC")
#
# NameError: name 'JC_distance' is not defined

# %% [markdown]
# # The Actual Algorithm

# %% [markdown]
# http://www.southampton.ac.uk/~re1u06/teaching/upgma/

# %% [markdown]
# ### *TODO: Introduction to Data Structures, lists and arrays/matrices , and trees *

# %% [markdown]
# Once again using abstraction assume that someone already has code that given a list of sequences produces a distance matrix.

# %%
pairwise_distances = JC_matrix_maker(HIV_seqs)
print(pairwise_distances)
# Out:
# [[ 0.          1.04725288  1.05048391  1.13837828  1.51596702  1.12434297]
#  [ 0.          0.          1.06679748  1.14191811  1.50062145  1.12783337]
#  [ 0.          0.          0.          1.14547051  1.52632981  1.14547051]
#  [ 0.          0.          0.          0.          1.51082562  1.1208647 ]
#  [ 0.          0.          0.          0.          0.          1.48550782]
#  [ 0.          0.          0.          0.          0.          0.        ]]

# %% [markdown]
# ### Discussion Question: With the above algorithms we can easily calculate the "pairwise" distances, ... so now what? Can we establish a connection between the dentist and the patiens HIV strains?

# %% [markdown]
# **Answer:** Making a tree from the pairwise distances is significantly more complicated of a task.  But fortunately a lot of very smart people have been thinking about this problem for a very long time, and they have developed a lot of very good algorithms to solve this problem.  One of the many algorithms used to do this is the "UPGMA" algorithm. Although "UPGMA" was not the Algorithm used by the investigators of the HIV dentist mystery, it is close enough of an approximation for the purposes of this workshop, and is a pre-requisite for understanding more sophisticated methods.

# %% [markdown]
# UPGMA is short for Unweighted Pair Group Method with Arithmetic Mean.  While this sounds like a mouthful, there is a great tutorial on http://www.southampton.ac.uk/~re1u06/teaching/upgma/ (click the link).

# %% [markdown]
# After Running UPGMA with the help of a package called ETE3 that makes really nice trees we obtained the following tree:

# %%
# Ignore this code
import IPython.display 
seq_cost = IPython.display.Image("http://i.imgur.com/TnD7gsh.png")
seq_cost

# %% [markdown]
# ## Resources and Acknowledgements:

# %% [markdown]
# https://www.genome.gov/images/content/costpergenome2015_4.jpg
#
# https://upload.wikimedia.org/wikipedia/commons/3/3f/Possible_evolutionary_trees_for_the_phylum_rotifera.png

# %% [markdown]
# http://www.southampton.ac.uk/~re1u06/teaching/upgma/
